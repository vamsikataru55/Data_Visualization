# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_16476\692205595.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
data=pd.read_csv("titanic.csv")
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...

# %%
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#     Ticket     Fare Cabin Embarked
# 0   330911   7.8292   NaN        Q
# 1   363272   7.0000   NaN        S
# 2   240276   9.6875   NaN        Q
# 3   315154   8.6625   NaN        S
# 4  3101298  12.2875   NaN        S

# %%
data.tail()
# Out:
#      PassengerId  Survived  Pclass                          Name     Sex  \
# 413         1305         0       3            Spector, Mr. Woolf    male
# 414         1306         1       1  Oliva y Ocana, Dona. Fermina  female
# 415         1307         0       3  Saether, Mr. Simon Sivertsen    male
# 416         1308         0       3           Ware, Mr. Frederick    male
# 417         1309         0       3      Peter, Master. Michael J    male
#
#       Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# 413   NaN      0      0           A.5. 3236    8.0500   NaN        S
# 414  39.0      0      0            PC 17758  108.9000  C105        C
# 415  38.5      0      0  SOTON/O.Q. 3101262    7.2500   NaN        S
# 416   NaN      0      0              359309    8.0500   NaN        S
# 417   NaN      1      1                2668   22.3583   NaN        C

# %%
data.shape
# Out:
# (418, 12)

# %%
data.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   418.000000  418.000000  418.000000  332.000000  418.000000
# mean   1100.500000    0.363636    2.265550   30.272590    0.447368
# std     120.810458    0.481622    0.841838   14.181209    0.896760
# min     892.000000    0.000000    1.000000    0.170000    0.000000
# 25%     996.250000    0.000000    1.000000   21.000000    0.000000
# 50%    1100.500000    0.000000    3.000000   27.000000    0.000000
# 75%    1204.750000    1.000000    3.000000   39.000000    1.000000
# max    1309.000000    1.000000    3.000000   76.000000    8.000000
#
#             Parch        Fare
# count  418.000000  417.000000
# mean     0.392344   35.627188
# std      0.981429   55.907576
# min      0.000000    0.000000
# 25%      0.000000    7.895800
# 50%      0.000000   14.454200
# 75%      0.000000   31.500000
# max      9.000000  512.329200

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Survived     418 non-null    int64
#  2   Pclass       418 non-null    int64
#  3   Name         418 non-null    object
#  4   Sex          418 non-null    object
#  5   Age          332 non-null    float64
#  6   SibSp        418 non-null    int64
#  7   Parch        418 non-null    int64
#  8   Ticket       418 non-null    object
#  9   Fare         417 non-null    float64
#  10  Cabin        91 non-null     object
#  11  Embarked     418 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 39.3+ KB

# %%
data.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %%
data.isnull().sum()/data.shape[0]*100
# Out:
# PassengerId     0.000000
# Survived        0.000000
# Pclass          0.000000
# Name            0.000000
# Sex             0.000000
# Age            20.574163
# SibSp           0.000000
# Parch           0.000000
# Ticket          0.000000
# Fare            0.239234
# Cabin          78.229665
# Embarked        0.000000
# dtype: float64

# %%
sns.boxplot(data["Fare"])
# Out:
# <Axes: ylabel='Fare'>

# %%
sns.countplot(x=data["Survived"])
# Out:
# <Axes: xlabel='Survived', ylabel='count'>

# %%
sns.histplot(x=data["Age"],kde=True)
# Out:
# <Axes: xlabel='Age', ylabel='Count'>

# %%
sns.displot(x=data["Age"])

# %%
sns.histplot(x=data["Survived"],kde=True)
# Out:
# <Axes: xlabel='Survived', ylabel='Count'>

# %%
sns.histplot(x=data["Fare"],kde=True)
# Out:
# <Axes: xlabel='Fare', ylabel='Count'>

# %%
sns.boxplot(data["Age"])
# Out:
# <Axes: ylabel='Age'>

# %%
#Filling the null in Age Column
data["Age"]=data["Age"].fillna(data["Age"].median())
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...

# %%
#In cabin column having more than 50% null values so, we are droping the cabin column
data.drop(["Cabin"],axis=True)
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...

# %%
#In Fare column having one null value.so, we are filling with median value
data["Fare"]=data["Fare"].fillna(data["Fare"].median())
data["Fare"].isnull().sum()
# Out:
# 0

# %%
df=data[["Age","Fare"]]
df
# Out:
#       Age      Fare
# 0    34.5    7.8292
# 1    47.0    7.0000
# 2    62.0    9.6875
# 3    27.0    8.6625
# 4    22.0   12.2875
# ..    ...       ...
# 413  27.0    8.0500
# 414  39.0  108.9000
# 415  38.5    7.2500
# 416  27.0    8.0500
# 417  27.0   22.3583
#
# [418 rows x 2 columns]

# %%
df.shape
# Out:
# (418, 2)

# %%
#Standard Scaling
from sklearn.preprocessing import StandardScaler

scaler=StandardScaler()
scaler.fit(df)
df1=scaler.transform(df)
df1
# Out:
# array([[ 0.38623105, -0.49741333],
#        [ 1.37137004, -0.51227801],
#        [ 2.55353683, -0.46410047],
#        [-0.20485235, -0.48247516],
#        [-0.59890794, -0.4174915 ],
#        [-1.2293969 , -0.47239149],
#        [ 0.03158101, -0.50099864],
#        [-0.28366347, -0.11789443],
#        [-0.91415242, -0.50816925],
#        [-0.67771906, -0.20483809],
#        [-0.20485235, -0.49621943],
#        [ 1.29255892, -0.17167401],
#        [-0.52009683,  0.83699245],
#        [ 2.63234795, -0.17167401],
#        [ 1.37137004,  0.45889154],
#        [-0.44128571, -0.14082605],
#        [ 0.42563661, -0.41637109],
#        [-0.67771906, -0.50824454],
#        [-0.20485235, -0.49569597],
#        [ 1.2137478 , -0.50824454],
#        [ 2.001859  ,  0.42707196],
#        [-1.6234525 , -0.58092226],
#        [-0.20485235, -0.06979219],
#        [-0.67771906,  0.46255214],
#        [ 1.45018116,  4.06570859],
#        [ 1.6078034 , -0.37782906],
#        [-0.59890794,  0.47330806],
# ...

# %%
df_scaled=pd.DataFrame(df1,columns=df.columns)
df_scaled
# Out:
#           Age      Fare
# 0    0.386231 -0.497413
# 1    1.371370 -0.512278
# 2    2.553537 -0.464100
# 3   -0.204852 -0.482475
# 4   -0.598908 -0.417492
# ..        ...       ...
# 413 -0.204852 -0.493455
# 414  0.740881  1.314435
# 415  0.701476 -0.507796
# 416 -0.204852 -0.493455
# 417 -0.204852 -0.236957
#
# [418 rows x 2 columns]

# %%
sns.boxplot(df_scaled["Age"])
# Out:
# <Axes: ylabel='Age'>

# %%
sns.boxplot(df_scaled["Fare"])
# Out:
# <Axes: ylabel='Fare'>

# %%
data1=pd.concat([data,df_scaled], axis=True)
data1
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...

# %%
data1.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          327
# Embarked         0
# Age              0
# Fare             0
# dtype: int64

# %%
data1=data1.dropna()
data1.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Cabin          0
# Embarked       0
# Age            0
# Fare           0
# dtype: int64

# %%
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...

# %%
dfr=data[["Age","Fare"]]
dfr
# Out:
#       Age      Fare
# 0    34.5    7.8292
# 1    47.0    7.0000
# 2    62.0    9.6875
# 3    27.0    8.6625
# 4    22.0   12.2875
# ..    ...       ...
# 413  27.0    8.0500
# 414  39.0  108.9000
# 415  38.5    7.2500
# 416  27.0    8.0500
# 417  27.0   22.3583
#
# [418 rows x 2 columns]

# %%
#Robust Scaling
from sklearn.preprocessing import RobustScaler

scaler = RobustScaler()
scaled_data = scaler.fit_transform(dfr)
scaled_df = pd.DataFrame(scaled_data, columns=dfr.columns)
print(scaled_df.head())
# Out:
#         Age      Fare
# 0  0.588235 -0.281005
# 1  1.568627 -0.316176
# 2  2.745098 -0.202184
# 3  0.000000 -0.245660
# 4 -0.392157 -0.091902

# %%
dfr_scaled=pd.DataFrame(scaled_df,columns=dfr.columns)
dfr_scaled
# Out:
#           Age      Fare
# 0    0.588235 -0.281005
# 1    1.568627 -0.316176
# 2    2.745098 -0.202184
# 3    0.000000 -0.245660
# 4   -0.392157 -0.091902
# ..        ...       ...
# 413  0.000000 -0.271640
# 414  0.941176  4.006002
# 415  0.901961 -0.305572
# 416  0.000000 -0.271640
# 417  0.000000  0.335259
#
# [418 rows x 2 columns]

# %%
sns.boxplot(dfr_scaled["Age"])
# Out:
# <Axes: ylabel='Age'>

# %%
sns.boxplot(dfr_scaled["Fare"])
# Out:
# <Axes: ylabel='Fare'>

# %%
data2=pd.concat([data,dfr_scaled], axis=True)
data2
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...
