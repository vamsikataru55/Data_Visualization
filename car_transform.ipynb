# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_6720\692205595.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
data=pd.read_csv("car_prices.csv")
data
# Out:
#         year    make                model         trim       body  \
# 0       2015     Kia              Sorento           LX        SUV
# 1       2015     Kia              Sorento           LX        SUV
# 2       2014     BMW             3 Series   328i SULEV      Sedan
# 3       2015   Volvo                  S60           T5      Sedan
# 4       2014     BMW  6 Series Gran Coupe         650i      Sedan
# ...      ...     ...                  ...          ...        ...
# 558832  2015     Kia                 K900       Luxury      Sedan
# 558833  2012     Ram                 2500  Power Wagon   Crew Cab
# 558834  2012     BMW                   X5    xDrive35d        SUV
# 558835  2015  Nissan               Altima        2.5 S      sedan
# 558836  2014    Ford                F-150          XLT  SuperCrew
#
#        transmission                vin state  condition  odometer   color  \
# 0         automatic  5xyktca69fg566472    ca        5.0   16639.0   white
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 558837 entries, 0 to 558836
# Data columns (total 16 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   year          558837 non-null  int64
#  1   make          548536 non-null  object
#  2   model         548438 non-null  object
#  3   trim          548186 non-null  object
#  4   body          545642 non-null  object
#  5   transmission  493485 non-null  object
#  6   vin           558833 non-null  object
#  7   state         558837 non-null  object
#  8   condition     547017 non-null  float64
#  9   odometer      558743 non-null  float64
#  10  color         558088 non-null  object
#  11  interior      558088 non-null  object
#  12  seller        558837 non-null  object
#  13  mmr           558799 non-null  float64
#  14  sellingprice  558825 non-null  float64
#  15  saledate      558825 non-null  object
# dtypes: float64(4), int64(1), object(11)
# memory usage: 68.2+ MB

# %%
from sklearn.preprocessing import LabelEncoder
encoder = LabelEncoder()

for col in data.select_dtypes(include=['object']).columns:
    data[col] = encoder.fit_transform(data[col])

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 558837 entries, 0 to 558836
# Data columns (total 16 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   year          558837 non-null  int64
#  1   make          558837 non-null  int32
#  2   model         558837 non-null  int32
#  3   trim          558837 non-null  int32
#  4   body          558837 non-null  int32
#  5   transmission  558837 non-null  int32
#  6   vin           558837 non-null  int32
#  7   state         558837 non-null  int32
#  8   condition     547017 non-null  float64
#  9   odometer      558743 non-null  float64
#  10  color         558837 non-null  int32
#  11  interior      558837 non-null  int32
#  12  seller        558837 non-null  int32
#  13  mmr           558799 non-null  float64
#  14  sellingprice  558825 non-null  float64
#  15  saledate      558837 non-null  int32
# dtypes: float64(4), int32(11), int64(1)
# memory usage: 44.8 MB

# %%
from sklearn.preprocessing import PowerTransformer
power = PowerTransformer()

for col in data.select_dtypes(include=[np.int64,np.float64,np.int32]).columns:
    data[col] = power.fit_transform(data[col].values.reshape(-1,1))

# %%
data.head()
# Out:
#                  year                make               model  \
# 0  PowerTransformer()  PowerTransformer()  PowerTransformer()
# 1  PowerTransformer()  PowerTransformer()  PowerTransformer()
# 2  PowerTransformer()  PowerTransformer()  PowerTransformer()
# 3  PowerTransformer()  PowerTransformer()  PowerTransformer()
# 4  PowerTransformer()  PowerTransformer()  PowerTransformer()
#
#                  trim                body        transmission  \
# 0  PowerTransformer()  PowerTransformer()  PowerTransformer()
# 1  PowerTransformer()  PowerTransformer()  PowerTransformer()
# 2  PowerTransformer()  PowerTransformer()  PowerTransformer()
# 3  PowerTransformer()  PowerTransformer()  PowerTransformer()
# 4  PowerTransformer()  PowerTransformer()  PowerTransformer()
#
#                   vin               state           condition  \
# 0  PowerTransformer()  PowerTransformer()  PowerTransformer()
# 1  PowerTransformer()  PowerTransformer()  PowerTransformer()
# ...

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor

features= data.select_dtypes(include=[np.int64,np.float64]).drop(['sellingprice'],axis=1)
target = data.select_dtypes(include=[np.int64,np.float64]).loc[:,'sellingprice']

x_train,x_test,y_train,y_test = train_test_split(features, target, test_size=0.2, random_state=214)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[47], line 4
#       1 from sklearn.model_selection import train_test_split
#       2 from sklearn.ensemble import RandomForestRegressor
# ----> 4 features= data.select_dtypes(include=[np.int64,np.float64]).drop(['sellingprice'],axis=1)
#       5 target = data.select_dtypes(include=[np.int64,np.float64]).loc[:,'sellingprice']
#       7 x_train,x_test,y_train,y_test = train_test_split(features, target, test_size=0.2, random_state=214)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\frame.py:5568, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5420 def drop(
#    5421     self,
#    5422     labels: IndexLabel | None = None,
#    (...)
#    5429     errors: IgnoreRaise = "raise",
# ...
